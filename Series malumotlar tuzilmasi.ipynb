# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
obj = Series([2, 5, 12, -4.5])

# %%
print(obj)
# Out:
# 0     2.0
# 1     5.0
# 2    12.0
# 3    -4.5
# dtype: float64
